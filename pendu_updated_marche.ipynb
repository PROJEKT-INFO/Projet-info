# %%
from turtle import *
import tkinter as tk
from random import *
import sys 
import random
def error1():
    up()
    width(5)
    goto(-180,-200)
    left(90)
    down()
    forward(500)
    right(90)
    forward(400)
    up()
    goto(-100,300)
    down()
    goto(-180,220)
    up()
    goto(220,300)
    down()
    right(90)
    forward(80)
    up()
    goto(-230,-200)
    down()
    left(90)
    forward(500)
    up()

def error2():
    goto(40,300)
    down()
    right(90)
    forward(100)
    right(90)
    fillcolor('pink')
    begin_fill()
    circle(50)
    end_fill()

def error3():
    left(90)
    up()
    goto(40,100)
    down()
    forward(100)

def error4():
    right(30)
    forward(80)
    backward(80)

def error5():
    left(60)
    forward(80)
    right(30)
    up()

def error6():
    goto(40,70)
    down()
    right(130)
    forward(70)
    backward(70)

def error7():
    left(260)
    forward(70)
    backward(70)
    up()

def error8():
    goto(20,155)
    down()
    dot(12)
    up()
    goto(60,155)
    down()
    dot(12)
    up()
    goto(30,125)
    down()
    forward(12)
    right(80)
    forward(12)
    up()
    hideturtle()
    goto(-400,280)
    down()
    write("P E R D U !",align="center",font=("Verdana", 20, "bold"))
    mainloop()

def error1_m():
    up()
    width(5)
    goto(-180,-200)
    left(90)
    down()
    forward(500)
    right(90)
    forward(400)
    up()
    goto(-100,300)
    down()
    goto(-180,220)
    up()
    goto(220,300)
    down()
    right(90)
    forward(80)
    up()
    goto(-230,-200)
    down()
    left(90)
    forward(500)
    up()

def error2_m():
    goto(40,300)
    down()
    right(90)
    forward(100)
    right(90)
    fillcolor('pink')
    begin_fill()
    circle(50)
    end_fill()
    left(90)
    up()
    goto(40,100)
    down()
    forward(100)

def error3_m():
    right(30)
    forward(80)
    backward(80)
    left(60)
    forward(80)
    right(30)
    up()

def error4_m():
    goto(40,70)
    down()
    right(130)
    forward(70)
    backward(70)
    left(260)
    forward(70)
    backward(70)
    up()

def error5_m():
    goto(20,155)
    down()
    dot(12)
    up()
    goto(60,155)
    down()
    dot(12)
    up()
    goto(30,125)
    down()
    forward(12)
    right(80)
    forward(12)
    up()
    hideturtle()
    goto(-400,280)
    down()
    write("P E R D U !",align="center",font=("Verdana", 20, "bold"))
    mainloop()

def error1_d():
    up()
    width(5)
    goto(-180,-200)
    left(90)
    down()
    forward(500)
    right(90)
    forward(400)
    up()
    goto(-100,300)
    down()
    goto(-180,220)
    up()
    goto(220,300)
    down()
    right(90)
    forward(80)
    up()
    goto(-230,-200)
    down()
    left(90)
    forward(500)
    up()
    goto(40,300)
    down()
    right(90)
    forward(100)
    right(90)
    fillcolor('pink')
    begin_fill()
    circle(50)
    end_fill()
    left(90)
    up()
    goto(40,100)
    down()
    forward(100)
    right(30)
    forward(80)
    backward(80)
    left(60)
    forward(80)
    right(30)
    up()

def error2_d():
    goto(40,70)
    down()
    right(130)
    forward(70)
    backward(70)
    left(260)
    forward(70)
    backward(70)
    up()
    goto(20,155)
    down()
    dot(12)
    up()
    goto(60,155)
    down()
    dot(12)
    up()
    goto(30,125)
    down()
    forward(12)
    right(80)
    forward(12)
    up()
    hideturtle()
    goto(-400,280)
    down()
    write("P E R D U !",align="center",font=("Verdana", 20, "bold"))
    mainloop()

#listes des mots du niveau facile
dic_5={"maison":"habitat pour les humains",
    "amour":"sentiment souvent représenté par un symbole",
    "danse":"sport qui s'accompagne souvent de musique",
    "sable":"ce qui tapisse le sol des lieux de vacances",
    "valse":"danse caractérisée par un mouvement de rotation",
    "avion": "permet de voyager dans le ciel",
    "olive":"fruit méditérranéen des apérots",
    "fusée":"voyage dans l'espace",
    "zumba":"jeu créer en 2001 inspiré de danses latines",
    "droit":"on a le côté gauche et le côté...",
    "Japon":"pays qui a capitulé après la WW2"}
dic_6={"soleil":"qui éclaire la terre",
    "tortue":"animal à carapace",
    "puzzle":"jeu d'assemblage calme",
    "bateau":"permet de voyager sur les eaux",
    "cactus":"plante que l'on trouve dans les zones désertiques",
    "Canada":"pays de l'érable",
    "Italie":"pays méditerranéen",
    "gauche":"on a le côté droit et le côté...",
    "saisons":"les 4 cycles de la nature",
    "Eglise":"lieu religieux",
    "auteur":"à l'origine d'un livre, projet",
    "montre":"sert à lire l'heure",}
dic_7={"banquise":"grande étendue de glace",
    "cartable":"sac utilisé pour l'école",
    "dessert":"plat sucré mangé à la fin du repas",
    "tornade":"vent très violent",
    "village":"petit groupe de maisons",
    "Pologne":"pays à  la frontière de l'Allemagne",
    "juillet":"mois de l'été",
    "Afrique":"continent riche en cultures, faunes et flores",
    "Espagne":"pays proche du Maroc",
    "voiture":"sert à se déplacer",
    "horloge":"lire l'heure"
    }
dic_8 = {"aventure":"histoire avec des événements imprévus",
    "boussole":"objet qui aide à se repérer",
    "telescope":"instrument pour observer les objets lointains",
    "grenouille":"animal qui saute et nage",
    "pyramide":"grand monument de forme triangulaire",
    "capitale":"ville principale d'un pays",
    "Belgique":"pays des frites",
    "Maldives":"Archipel paradisiaque",
    }
ind="aucun"


#liste de mots du niveau moyen 
dic_5_m={"Aigle":"oiseau prestigieux",
          "Gifle":"frapper quelqu'un à un endroit précis",
          "Radis":"légume bicolore",}

dic_6_m={"Ananas":"fruit exotique",
        "Tétine":"objet particulièrement affectioné par les bébés",
        "Hurler":"action qui signale un danger ou une douleur",
        "Séisme":"onde terrestre",
        "casino":"jeux d'argent"}

dic_7_m={"Losange":"forme géométrique à 4 côtés",
        "Scooter":"2 roues",
        "Journal":"moyen de s'informer avant la télé ", 
        "Corbeau":"à vos risques et périls si vous lui faites mal"}

dic_8_m={"Brocante":"endroit pour vendre et faire de la place dans ses placards", 
        "Diapason":"instrument de résonnance utilisé en physique",
        "Archipel":"Indonésie ou Japon ou l'ensemble des îles océaniques",
        "Symptôme":"ensemble de signes qui alertent sur une situation ou indique que quelque chose arrive"}

#liste de mots du niveau difficile

dic_5_d={"Klaxon":"bruit interdit la nuit et en ville", 
        "Sable":"rappelle l'été", 
        "Trêve":"pause particulière", 
        "Fable":"courtes histoires", 
        "Capot":"élément important d'une voiture"}

dic_6_d={"Quartz":"pierre à couleur douce utilisée dans les bijoux",
        "Sphinx":"animal mythique", "Acajou":"couleur spécifique du marron ou bois tropical", 
        "Zipper":"action de fermer quelque chose comme une veste"}

dic_7_d={"Dentier":"quand on a plus de dents on en met",
         "Ukulélé":"instrument qui ressemble au violon",
         "Zozoter":"quand on arrive pas à bien prononcer des lettres spécifiques"}

dic_8_d={"Trousseau":"généralement utiliser pour les clés",
        "Brouette":"objet à roues utile pour transporter des objets",
        "Fracture":"Rupture d'une ligne ou élément; utilisé en milieu médical",
        "Alchimie":"ce qu'on appelle de science et qui a 2 but principaux"}



#nombre d'erreurs maximale en fonction du niveau choisi
# erreurs_max = {
#     "facile": 8,
#     "moyen": 5,
#     "difficile": 2
#     }


# création de la fenêtre tkinter (avec assistance d'ia)
def rejouer():
    resetscreen()
    jeu()

#création bouton quitter
def quitter():
    sys.exit(0)


#création de la fenêtre de fin avec quitter et rejouer
def fenetre_fin():
    root = tk.Tk()
    root.title("Partie terminée")
    root.geometry("600x300")
    label = tk.Label(root, text="Cliquez sur un bouton si vous souhaitez sortir ou rejouer")
    label.pack(pady=10)
    bouton_rejouer = tk.Button(root, text="Rejouer", command=lambda: [root.destroy(), rejouer()])
    bouton_rejouer.pack(pady=5)
    bouton_quitter = tk.Button(root, text="Quitter", command=lambda: [root.destroy(), quitter()])
    bouton_quitter.pack(pady=5)
    root.mainloop()


def jeu():
    length = numinput("Longueur du mot", "choisissez la longueur du mot allant de 5 à 8:")
    niveau = textinput("Niveau du jeu", "choisir un niveau pour jouer entre facile, moyen ou difficile")

    if length < 5 or length > 8 and niveau != ("facile" or "difficile" or "moyen") :
        length = numinput("Longueur du mot", "choix incorrect, choisissez la longueur du mot allant de 5 à 8:")
        niveau = textinput("Niveau du jeu", "veuillez taper un niveau pour jouer")

    dic_du_niveau={}
    nb_erreurs_max = 0
    
    
    if niveau == "facile":

        erreurs = [error1, error2, error3, error4, error5, error6, error7, error8]
        nb_erreurs_max = 8

        if length == 5:
            dic_du_niveau=dic_5
            
        elif length == 6:
            dic_du_niveau=dic_6
            
        elif length == 7:
            dic_du_niveau=dic_7
            
        else:
            dic_du_niveau=dic_8
            

        mot_a_deviner = random.choice(list(dic_du_niveau.keys()))
        indice_du_mot_a_deviner=dic_du_niveau[mot_a_deviner]

        mots=mot_a_deviner.lower()


    elif niveau == "moyen":
        nb_erreurs_max=5
        erreurs = [error1_m, error2_m, error3_m, error4_m, error5_m]
        if length == 5:
            dic_du_niveau=dic_5_m
        elif length == 6:
            dic_du_niveau=dic_6_m
        elif length == 7:
            dic_du_niveau=dic_7_m
        else:
            dic_du_niveau=dic_8_m

        mot_a_deviner = random.choice(list(dic_du_niveau.keys()))
        indice_du_mot_a_deviner=dic_du_niveau[mot_a_deviner]

        mots=mot_a_deviner.lower()

    else:
        nb_erreurs_max=2
        erreurs = [error1_d, error2_d]
        if length == 5:
            dic_du_niveau=dic_5_d
        elif length == 6:
            dic_du_niveau=dic_6_d
        elif length == 7:
            dic_du_niveau=dic_7_d
        else:
            dic_du_niveau=dic_8_d

        mot_a_deviner = random.choice(list(dic_du_niveau.keys()))
        indice_du_mot_a_deviner=dic_du_niveau[mot_a_deviner]

        mots=mot_a_deviner.lower()

    trouvés = []
    poubelle = []
    nb_erreurs=0
    écrit = Turtle()
    indice = Turtle()
    indice.hideturtle()


    for i in range(len(mots)):
        trouvés.append("*")

    while trouvés != list(mots) and nb_erreurs < nb_erreurs_max:
        affiche = "".join(trouvés)
        écrit.clear()
        écrit.hideturtle()
        écrit.up()
        écrit.goto(0, -260)
        écrit.write(affiche, align="center", font=("Verdana", 22, "bold"))
        
        lettre = textinput("LETTRE", "entrez la lettre ci-dessous, ou:\n-tapez 'sortie' pour quitter le jeu\n-tapez 'indice' pour en obtenir un")
        
        if lettre == "sortie" or lettre is None:
            break
        
        if lettre == "indice":
            indice.clear()
            indice.up()
            indice.goto(0, -320)
            indice.write(indice_du_mot_a_deviner, align="center", font=("Verdana", 14, "bold"))
            indice.hideturtle()
        
        elif lettre in mots:
            if lettre in trouvés:
                textinput("INFORMATION", "Lettre déjà sélectionnée auparavant !\nClique sur OK pour continuer.")
            else:
                for i, j in enumerate(mots):
                    if j == lettre:
                        trouvés[i] = lettre
        
        else:
            if lettre in poubelle:
                textinput("INFORMATION", "Lettre déjà sélectionnée auparavant !\nClique sur OK pour continuer.")
            else:
                poubelle.append(lettre)
                erreurs[nb_erreurs]() 
                nb_erreurs += 1

    if trouvés == list(mots):
        écrit.reset()
        indice.reset()
        reset()
        write("G A G N É ! ! !", align="center", font=("Verdana", 25, "bold"))
        hideturtle()
        fenetre_fin() 
    
    elif nb_erreurs == nb_erreurs_max:
        reset()
        write(f"P E R D U\nLe mot était: {''.join(mots)}", align="center", font=("Verdana", 20, "bold"))
        hideturtle()
        fenetre_fin()


jeu()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[4], line 508
#     504         hideturtle()
#     505         fenetre_fin()
# --> 508 jeu()
#
# Cell In[4], line 502, in jeu()
#     499     fenetre_fin()
#     501 elif nb_erreurs == nb_erreurs_max:
# --> 502     reset()
#     503     write(f"P E R D U\nLe mot était: {''.join(mots)}", align="center", font=("Verdana", 20, "bold"))
#     504     hideturtle()
#
# File <string>:5, in reset()
#
# Terminator:
